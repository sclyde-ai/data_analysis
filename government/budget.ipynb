# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
# データ読み込みと前処理
data = pd.read_excel('/home/sclyde/home/finance/data/ministry_of_finance/budget/general/DL202511001.xlsx')
columns = data.columns
data = data.drop(axis=1, labels=columns[1:5])

# 府省データの抽出
ministry_index = data.dropna(subset=columns[0]).drop(axis=1, labels=columns[5:9]).iloc[:, 0].index
ministry = data.dropna(subset=columns[0]).drop(axis=1, labels=columns[5:9])

# 府省ごとの円グラフ作成関数
def plot_ministry_pie(ministry_name, values, labels, total):
    plt.figure(figsize=(8, 8))
    
    # パーセントと絶対値を表示するカスタム関数
    def autopct_format(pct):
        amount = int(pct/100000. * total)
        return f'{pct:.1f}%\n{amount:,} milion'
    
    # 円グラフ描画
    wedges, texts, autotexts = plt.pie(
        values,
        labels=labels,
        autopct=autopct_format,
        startangle=90,
        textprops={'fontsize': 10}
    )
    
    # タイトルに府省名と総額を表示
    plt.title(
        f'{ministry_name}\nTotal Budget: ¥{total:,}', 
        fontsize=14,
        pad=20
    )
    
    # 凡例を追加
    # plt.legend(
    #     wedges,
    #     [f'{l} - ¥{v:,}' for l, v in zip(labels, values)],
    #     title="Budget Items",
    #     loc="center left",
    #     bbox_to_anchor=(1, 0, 0.5, 1)
    # )
    
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
    plt.close()

# 府省ごとの主要予算項目を分析
ministry_data = {}
for i in range(len(ministry)):
    ministry_name = ministry.iloc[i, 0]
    
    # 府省データの抽出
    if i < len(ministry)-1:
        ministry_data[ministry_name] = data.iloc[ministry_index[i]:ministry_index[i+1]-1]
    else:
        ministry_data[ministry_name] = data.iloc[ministry_index[i]:len(data)-1]
    
    # 予算項目データの処理
    item_data = ministry_data[ministry_name].dropna(subset=columns[8]).dropna(axis=1)
    item_data = item_data.sort_values(by=columns[9], ascending=False)
    
    # 上位10項目のみ表示（多すぎると見づらいため）
    top_items = item_data.head(10)
    
    # 総額計算
    total_budget = int(top_items.iloc[:, 1].sum())
    
    # 円グラフ描画
    plot_ministry_pie(
        ministry_name=ministry_name,
        values=top_items.iloc[:, 1],
        labels=top_items.iloc[:, 0],
        total=total_budget
    )
    
    # データ確認用に出力
    print(f"\n=== {ministry_name} ===")
    print(f"Total Budget: ¥{total_budget:,}")
    print(top_items)
# Out:
# === 国会 ===
# Total Budget: ¥216,922.8
#                    部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 4                 土地及水面貸付料       1325420     1263552       61868
# 5                 建物及物件貸付料        731201      729693        1508
# 12                     返納金         55140       52831        2309
# 6                 公務員宿舎貸付料         38380       38014         366
# 14                 不用物品売払代         13143       12144         999
# 16            労働保険料被保険者負担金          4787        5129        -342
# 11                  弁償及違約金           866         322         544
# 8                版権及特許権等収入           267         332         -65
# 17                     延滞金            24           2          22
# === 裁判所 ===
# Total Budget: ¥564,361.2
#                    部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 23              修習資金貸与金償還金       2688802     2610504       78298
# 37                     手数料       1880983     1806623       74360
# 29                公務員宿舎貸付料        389339      393487       -4148
# 40                     没収金        177055      229438      -52383
# 28                建物及物件貸付料        159975      165941       -5966
# 27                土地及水面貸付料         96577       95016        1561
# 43                     返納金         79197       63138       16059
# 42                  弁償及違約金         69422       62628        6794
# 45                 不用物品売払代         52782       49029        3753
# 34             法科大学院設置者納付金         49480       48980         500
# === 会計検査院 ===
# Total Budget: ¥748.0
#                    部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 62                     返納金          2904        2532         372
# 66            労働保険料被保険者負担金          2391        3060        -669
# 64                 不用物品売払代          1198        1244         -46
# 58                公務員宿舎貸付料           792        1104        -312
# 57                建物及物件貸付料           120          74          46
# 61                  弁償及違約金            57          57           0
# 56                土地及水面貸付料            17          17           0
# 67                     延滞金             1           1           0
# === 内閣 ===
# Total Budget: ¥94,534.9
#                    部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 81                     返納金        887995      843583       44412
# 73                土地及水面貸付料         28420       28105         315
# 80                  弁償及違約金         18464         481       17983
# 85            労働保険料被保険者負担金          4380        4306          74
# 75                公務員宿舎貸付料          2318        2745        -427
# 83                 不用物品売払代          1822        2056        -234
# 74                建物及物件貸付料          1628        1514         114
# 77               版権及特許権等収入           310         290          20
# 86                     延滞金            12          11           1
# === 内閣府 ===
# Total Budget: ¥9,533,966.5
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 129                 交通反則者納金      47115029    48493496    -1378467
# 132                     返納金      28420011    65303135   -36883124
# 103        母子父子寡婦福祉資金貸付金償還金      10259955    11416882    -1156927
# 114         警察共通基盤システム利用料収入       4009679           0     4009679
# 102            災害援護資金貸付金償還金       1720518     2361352     -640834
# 118             価格協定等違反者納付金       1119587     2488197    -1368610
# 127                     手数料        997225     1014735      -17510
# 112                  入場料等収入        653770      510407      143363
# 109                公務員宿舎貸付料        534748      539767       -5019
# 120              不当表示違反者納付金        509143      642327     -133184
# === デジタル庁 ===
# Total Budget: ¥2,190.0
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 147                     返納金         14080       13132         948
# 149            労働保険料被保険者負担金          7695        8545        -850
# 144                     手数料           124         117           7
# 146                  弁償及違約金             1           1           0
# === 総務省 ===
# Total Budget: ¥10,059,904.7
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 171                 電波利用料収入      75000000    74995721        4279
# 173              特定基地局開設料収入      13600000    13600000           0
# 167                     返納金       9800493     6508562     3291931
# 164                     手数料       1449581     1593504     -143923
# 160         独立行政法人統計センター納付金        548135      474366       73769
# 156                建物及物件貸付料         75157       74621         536
# 155                土地及水面貸付料         59627       59188         439
# 157                公務員宿舎貸付料         27199       26426         773
# 169                 不用物品売払代         25226       41168      -15942
# 175            労働保険料被保険者負担金         13629       16228       -2599
# === 法務省 ===
# Total Budget: ¥10,446,928.4
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 189                     手数料      63093077    58760546     4332531
# 193                   罰金及科料      33482519    32812124      670395
# 200                 刑務所作業収入       2444348     2428520       15828
# 191                      過料       1405233     1513742     -108509
# 192                     没収金       1298658     1052979      245679
# 196                     返納金        906237      623845      282392
# 207             相続土地国庫帰属負担金        679368      679368           0
# 198                 不用物品売払代        456544      433253       23291
# 195                  弁償及違約金        402206      402858        -652
# 183                建物及物件貸付料        301094      295086        6008
# === 外務省 ===
# Total Budget: ¥2,905,136.6
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 228                     返納金      18094029    17916562      177467
# 225                     手数料      10151128     7337291     2813837
# 220                公務員宿舎貸付料        637958      559425       78533
# 230                 不用物品売払代         46043       43667        2376
# 213                   土地売払代         40033       15962       24071
# 219                建物及物件貸付料         32024       50481      -18457
# 222                 預託金利子収入         18468       10202        8266
# 214                   建物売払代         14577       13811         766
# 218                土地及水面貸付料         10064       10012          52
# 232            労働保険料被保険者負担金          7042        7097         -55
# === 財務省 ===
# Total Budget: ¥10,539,524,320.1
#                     部・款・項・目  令和7年度予算額(千円)   前年度予算額(千円)   比較増△減額(千円)
# 246                     消費税   24908000000  24343000000    565000000
# 360                   特例公債金   21858000000  32480000000 -10622000000
# 242                     法人税   19245000000  18054000000   1191000000
# 239                   源泉所得税   18808000000  15792000000   3016000000
# 358                     公債金    6791000000   9659000000  -2868000000
# 240                   申告所得税    4479000000   4317000000    162000000
# 244                     相続税    3461000000   3387000000     74000000
# 325           外国為替資金特別会計受入金    2202022041   1238475863    963546178
# 252                    揮発油税    1976000000   2018000000    -42000000
# 348               防衛力強化資金受入    1667221160   1154824165    512396995
# === 文部科学省 ===
# Total Budget: ¥9,813,175.4
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 375              育英資金貸付金償還金      58144250    56880897     1263353
# 400                     返納金      22686531    25368402    -2681871
# 386   独立行政法人日本スポーツ振興センター納付金       9682937     6210642     3472295
# 406           原子力損害賠償補償料等収入       4407464     4395301       12163
# 390   国立研究開発法人日本医療研究開発機構納付金       2050303        4188     2046115
# 379                土地及水面貸付料        763807      768507       -4700
# 397                     手数料        337807      328448        9359
# 380                建物及物件貸付料         29476       28728         748
# 381                公務員宿舎貸付料         17961       20371       -2410
# 383               版権及特許権等収入         11218       12026        -808
# === 厚生労働省 ===
# Total Budget: ¥62,524,078.9
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 440                     返納金     622612564   642929845   -20317281
# 412  国立障害者リハビリテーションセンター病院収入        734841      652392       82449
# 451                      雑収        566081      622621      -56540
# 421                土地及水面貸付料        382489      371253       11236
# 450         労働保険審査会費特別会計負担金        319144      311920        7224
# 439                  弁償及違約金        236819      137347       99472
# 428               年金特別会計受入金        143461      108371       35090
# 448                     延滞金        108767       38636       70131
# 430                     授業料         74683       69355        5328
# 437                  受託造修収入         61940       63760       -1820
# === 農林水産省 ===
# Total Budget: ¥48,193,449.6
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 484              日本中央競馬会納付金     371458790   369971609     1487181
# 464                国有林野事業収入      36178061    38296112    -2118051
# 499              土地改良事業費負担金      36054541    41546851    -5492310
# 521                     返納金      20233080    24980754    -4747674
# 516                  受託工事収入       6585515     6181297      404218
# 501          特定漁港漁場整備事業費負担金       4028205     5496900    -1468695
# 498                治山事業費負担金       3287431     4321405    -1033974
# 493           食料安定供給特別会計受入金       2646198     2590213       55985
# 497              海岸整備事業費負担金        829596      993716     -164120
# 479                公務員宿舎貸付料        633079      656610      -23531
# === 経済産業省 ===
# Total Budget: ¥1,348,213.5
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 545           特定アルコール譲渡者納付金       8229830    10070120    -1840290
# 556                     返納金       3740042  1213461444 -1209721402
# 562                      雑収       1004001      976954       27047
# 547    国立研究開発法人産業技術総合研究所納付金        273720           0      273720
# 558                 不用物品売払代         94513       94359         154
# 540                土地及水面貸付料         58926       58365         561
# 541                建物及物件貸付料         39051       97384      -58333
# 536     小規模企業者等設備導入資金貸付金償還金         15810       40606      -24796
# 560            労働保険料被保険者負担金         15180       16299       -1119
# 542                公務員宿舎貸付料         11062        8957        2105
# === 国土交通省 ===
# Total Budget: ¥64,552,550.4
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 609              道路整備事業費負担金     289313000   350879530   -61566530
# 607             河川等整備事業費負担金     129517170   181448620   -51931450
# 610              港湾整備事業費負担金      60345080    86455855   -26110775
# 572        社会資本整備事業特別会計整理収入      57169146    57281843     -112697
# 621                  受託工事収入      34673122    60926008   -26252886
# 608  多目的ダム建設等事業電気事業者等工事費負担金      34042341    34542380     -500039
# 632                附帯工事費負担金      15485575    19558833    -4073258
# 575          有料道路整備資金貸付金償還金      11263120    11870584     -607464
# 627                     返納金       7356248    23336678   -15980430
# 617                     許可料       6360702     6454552      -93850
# === 環境省 ===
# Total Budget: ¥336,982.6
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 652                     返納金       1788666     1724805       63861
# 642                土地及水面貸付料        833818      816363       17455
# 646                  入場料等収入        550437      345441      204996
# 643                建物及物件貸付料         74172       72959        1213
# 658                      雑収         64503       72309       -7806
# 649                     手数料         29453       30241        -788
# 644                公務員宿舎貸付料         12987       12357         630
# 651                  弁償及違約金          6294        5590         704
# 656            労働保険料被保険者負担金          5942        5800         142
# 657                     延滞金          3554        1354        2200
# === 防衛省 ===
# Total Budget: ¥7,407,447.8
#                     部・款・項・目  令和7年度予算額(千円)  前年度予算額(千円)  比較増△減額(千円)
# 703                     返納金      41490493    25472280    16018213
# 668                 防衛省病院収入      14805421    16339709    -1534288
# 702                  弁償及違約金       4624323     4778559     -154236
# 683                公務員宿舎貸付料       4617620     4941129     -323509
# 711                   給食費受入       2885572     2655649      229923
# 705                 不用物品売払代       2504701     2089132      415569
# 682                建物及物件貸付料       1208439     1139093       69346
# 681                土地及水面貸付料       1163927     1084205       79722
# 675           自衛隊奨学生貸与金等償還金        489133      610024     -120891
# 672                   船舶売払代        284849       87425      197424
