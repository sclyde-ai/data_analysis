# %%
budget_hierarchy = {
    "国会": {
        "雑収入": {
            "国有財産利用収入": {
                "国有財産貸付収入": {
                    "土地及水面貸付料": {},
                    "建物及物件貸付料": {},
                    "公務員宿舎貸付料": {}
                },
                "国有財産使用収入": {
                    "版権及特許権等収入": {}
                }
            },
            "諸収入": {
                "弁償及返納金": {
                    "弁償及違約金": {},
                    "返納金": {}
                },
                "物品売払収入": {
                    "不用物品売払代": {}
                },
                "雑入": {
                    "労働保険料被保険者負担金": {},
                    "延滞金": {},
                    "雑収": {}
                }
            }
        }
    },
    "裁判所": {
        "政府資産整理収入": {
            "回収金等収入": {
                "貸付金等回収金収入": {
                    "修習資金貸与金償還金": {}
                }
            }
        },
        "雑収入": {
            "国有財産利用収入": {
                "国有財産貸付収入": {
                    "土地及水面貸付料": {},
                    "建物及物件貸付料": {},
                    "公務員宿舎貸付料": {}
                },
                "国有財産使用収入": {
                    "版権及特許権等収入": {}
                }
            },
            "納付金": {
                "法科大学院設置者納付金": {
                    "法科大学院設置者納付金": {}
                }
            },
            "諸収入": {
                "許可及手数料": {
                    "手数料": {}
                },
                "懲罰及没収金": {
                    "過料": {},
                    "没収金": {}
                },
                "弁償及返納金": {
                    "弁償及違約金": {},
                    "返納金": {}
                },
                "物品売払収入": {
                    "不用物品売払代": {}
                },
                "雑入": {
                    "労働保険料被保険者負担金": {},
                    "小切手支払未済金収入": {},
                    "延滞金": {},
                    "期満後収入": {},
                    "雑収": {}
                }
            }
        }
    },
    "会計検査院": {
        "雑収入": {
            "国有財産利用収入": {
                "国有財産貸付収入": {
                    "土地及水面貸付料": {},
                    "建物及物件貸付料": {},
                    "公務員宿舎貸付料": {}
                }
            },
            "諸収入": {
                "弁償及返納金": {
                    "弁償及違約金": {},
                    "返納金": {}
                },
                "物品売払収入": {
                    "不用物品売払代": {}
                },
                "雑入": {
                    "労働保険料被保険者負担金": {},
                    "延滞金": {},
                    "雑収": {}
                }
            }
        }
    }
}
