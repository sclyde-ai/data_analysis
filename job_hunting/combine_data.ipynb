# %%
import os
import glob
import pandas as pd
from openpyxl import load_workbook

# 設定部分 ================================================
target_dir = "2024"  # Excelファイルが入っているディレクトリ
output_file = "job_hunting.xlsx"  # 出力ファイル名
exclude_files = []  # 除外するファイル名（任意）
# ========================================================

# 対象ディレクトリ内の全Excelファイルを取得
file_paths = glob.glob(os.path.join(target_dir, "*.xlsx")) + \
             glob.glob(os.path.join(target_dir, "*.xls"))

# 除外ファイルをフィルタリング
file_paths = [f for f in file_paths if os.path.basename(f) not in exclude_files]

if not file_paths:
    print("結合対象のExcelファイルが見つかりませんでした。")
else:
    print(f"結合対象ファイル ({len(file_paths)}件):")
    for f in file_paths:
        print(f"- {os.path.basename(f)}")

    # ExcelWriterで出力
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        for file_path in file_paths:
            try:
                # シート名生成（ファイル名から拡張子と不正文字を除去）
                sheet_name = os.path.splitext(os.path.basename(file_path))[0]
                sheet_name = sheet_name[:31]  # シート名最大31文字
                sheet_name = "".join(c for c in sheet_name if c not in r'\/?*[]:')

                # データ読み込み
                df = pd.read_excel(file_path)
                
                # シートとして追加
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"[OK] {os.path.basename(file_path)} -> シート名: '{sheet_name}'")
            except Exception as e:
                print(f"[ERROR] {os.path.basename(file_path)} の処理に失敗: {str(e)}")

    print(f"\n結合完了: {output_file} (シート数: {len(file_paths)})")
# Out:
# 結合対象ファイル (217件):
# - 三菱ＵＦＪ信託銀行.xlsx
# - 三井住友海上火災保険.xlsx
# - 大林組.xlsx
# - 神戸製鋼所.xlsx
# - 読売新聞社.xlsx
# - 味の素.xlsx
# - 森永乳業.xlsx
# - 日本経済新聞社.xlsx
# - 三菱電機.xlsx
# - コナミグループ.xlsx
# - 伊藤園.xlsx
# - 双日.xlsx
# - アクセンチュア.xlsx
# - ＪＦＥグループ.xlsx
# - 九州電力.xlsx
# - ＮＨＫ.xlsx
# - ドコモグループ.xlsx
# - 鹿島.xlsx
# - ＡＬＳＯＫ.xlsx
# - ゆうちょ銀行.xlsx
# - 大和ハウス工業.xlsx
# - ＢＩＰＲＯＧＹ.xlsx
# - 博報堂／博報堂ＤＹメディアパートナーズ.xlsx
# - ＮＥＣ.xlsx
# - ＮＴＴ西日本.xlsx
# - 竹中工務店.xlsx
# - ホンダ.xlsx
# - ＴＤＫ.xlsx
# - テレビ東京.xlsx
# - ＩＨＩ.xlsx
# - 清水建設.xlsx
# - 三井住友信託銀行.xlsx
# - ＪＲ東海.xlsx
# - 野村総合研究所.xlsx
# - 東レ.xlsx
# - 小学館.xlsx
# - かんぽ生命保険.xlsx
# - アビームコンサルティング.xlsx
# - 塩野義製薬.xlsx
# - キヤノン.xlsx
# - 丸紅.xlsx
# - 東芝.xlsx
# - 日本郵政.xlsx
# - 中部電力.xlsx
# - 毎日新聞社.xlsx
# - ＮＴＴデータグループ.xlsx
# - 大成建設.xlsx
# - デンソー.xlsx
# - 富士フイルム.xlsx
# - 三菱ＵＦＪ銀行.xlsx
# - ＬＩＸＩＬ.xlsx
# - レゾナック.xlsx
# - シャープ.xlsx
# - マツダ.xlsx
# - 日本製鉄.xlsx
# - リコー.xlsx
# - 岡三証券.xlsx
# - ＹＫＫ／ＹＫＫ ＡＰ.xlsx
# - ＪＲ西日本.xlsx
# - 日本テレビ放送網.xlsx
# - 講談社.xlsx
# - エーザイ.xlsx
# - 住友生命保険.xlsx
# - テルモ.xlsx
# - アコム.xlsx
# - いすゞ自動車.xlsx
# - 良品計画.xlsx
# - 積水ハウス.xlsx
# - サイバーエージェント.xlsx
# - 大塚商会.xlsx
# - 第一生命保険.xlsx
# - 東京電力.xlsx
# - 中外製薬.xlsx
# - 集英社.xlsx
# - 花王.xlsx
# - クボタ.xlsx
# - 三菱商事.xlsx
# - フジテレビジョン.xlsx
# - ＰｗＣコンサルティング.xlsx
# - ミネベアミツミ.xlsx
# - 関西電力.xlsx
# - みずほフィナンシャルグループ.xlsx
# - オリエンタルランド.xlsx
# - 商工組合中央金庫.xlsx
# - 電通.xlsx
# - 明治安田生命保険.xlsx
# - 損害保険ジャパン.xlsx
# - 野村不動産.xlsx
# - 東京エレクトロングループ.xlsx
# - 日揮ホールディングス.xlsx
# - ニトリ.xlsx
# - 住友電気工業.xlsx
# - ＥＮＥＯＳ.xlsx
# - ＴＢＳテレビ.xlsx
# - 東京海上日動火災保険.xlsx
# - 東海東京フィナンシャル・ホールディングス.xlsx
# - キユーピー.xlsx
# - 三菱ＵＦＪニコス.xlsx
# - 大塚製薬.xlsx
# - 三菱マテリアル.xlsx
# - オービック.xlsx
# - ローソン.xlsx
# - セブン‐イレブン・ジャパン.xlsx
# - パナソニック.xlsx
# - 日本生命保険.xlsx
# - ヤマハ発動機.xlsx
# - トヨタ自動車.xlsx
# - ソニーグループ.xlsx
# - 三井住友銀行.xlsx
# - タカラスタンダード.xlsx
# - 日立ソリューションズ.xlsx
# - 三井不動産.xlsx
# - 関西みらい銀行.xlsx
# - ＪＲ東日本.xlsx
# - 日本航空.xlsx
# - ＡＧＣ.xlsx
# - ＪＴ.xlsx
# - ＴＯＴＯ.xlsx
# - あいおいニッセイ同和損害保険.xlsx
# - リクルート.xlsx
# - りそなグループ.xlsx
# - 明治グループ.xlsx
# - 日本銀行.xlsx
# - ＮＴＴ東日本.xlsx
# - ローム.xlsx
# - 戸田建設.xlsx
# - セキスイハイムグループ.xlsx
# - Ｓｋｙ.xlsx
# - 東北電力.xlsx
# - 村田製作所.xlsx
# - 野村証券.xlsx
# - ＮＥＣソリューションイノベータ.xlsx
# - トランスコスモス.xlsx
# - 住友商事.xlsx
# - 三井物産.xlsx
# - エイチ・アイ・エス.xlsx
# - ＳＭＢＣ日興証券.xlsx
# - 大阪ガス.xlsx
# - 川崎重工業.xlsx
# - 伊藤忠商事.xlsx
# - 日本通運.xlsx
# - 三井化学.xlsx
# - ベネッセコーポレーション.xlsx
# - 横浜銀行.xlsx
# - 第一三共.xlsx
# - キリン.xlsx
# - デロイトトーマツコンサルティング.xlsx
# - ＮＴＴ（持株会社）.xlsx
# - 日本ＩＢＭ.xlsx
# - 京都銀行.xlsx
# - 日産自動車.xlsx
# - 富士電機.xlsx
# - 豊田自動織機.xlsx
# - ＪＴＢ.xlsx
# - 三菱地所.xlsx
# - 東京ガス.xlsx
# - ＳＣＳＫ.xlsx
# - 旭化成グループ.xlsx
# - ルネサスエレクトロニクス.xlsx
# - サントリーグループ.xlsx
# - ＴＩＳ.xlsx
# - 朝日新聞社.xlsx
# - アステラス製薬.xlsx
# - 古河電気工業.xlsx
# - 日本郵便.xlsx
# - メイテック.xlsx
# - 大日本印刷.xlsx
# - 長谷工コーポレーション.xlsx
# - 出光興産.xlsx
# - ジェーシービー.xlsx
# - ＴＯＰＰＡＮ.xlsx
# - スズキ.xlsx
# - 三菱重工業.xlsx
# - オリエントコーポレーション.xlsx
# - アルファシステムズ.xlsx
# - 福岡銀行.xlsx
# - 三菱自動車工業.xlsx
# - 山崎製パン.xlsx
# - 大和証券.xlsx
# - 住友化学.xlsx
# - アマゾンジャパン.xlsx
# - ＥＹストラテジー・アンド・コンサルティング.xlsx
# - 京セラ.xlsx
# - ＫＤＤＩ.xlsx
# - ダイハツ工業.xlsx
# - ＫＡＤＯＫＡＷＡ.xlsx
# - 青山商事.xlsx
# - 五洋建設.xlsx
# - ＳＵＢＡＲＵ.xlsx
# - セイコーエプソン.xlsx
# - ファーストリテイリンググループ.xlsx
# - ＬＩＮＥヤフー.xlsx
# - 楽天グループ.xlsx
# - 日東電工.xlsx
# - コマツ.xlsx
# - 住友林業.xlsx
# - 千葉銀行グループ.xlsx
# - 富士ソフト.xlsx
# - 静岡銀行.xlsx
# - 東武トップツアーズ.xlsx
# - 積水化学工業.xlsx
# - 日立システムズ.xlsx
# - インテック.xlsx
# - 富士通.xlsx
# - 日本政策金融公庫.xlsx
# - 三菱ＵＦＪモルガン・スタンレー証券.xlsx
# - アイシン.xlsx
# - キヤノンマーケティングジャパン.xlsx
# - オリックス.xlsx
# - キーエンス.xlsx
# - セコム.xlsx
# - 全日本空輸.xlsx
# - ソフトバンク.xlsx
# - 富士フイルムビジネスイノベーション.xlsx
# - 日立製作所.xlsx
# - ダイキン工業.xlsx
# - テレビ朝日.xlsx
# [OK] 三菱ＵＦＪ信託銀行.xlsx -> シート名: '三菱ＵＦＪ信託銀行'
# [OK] 三井住友海上火災保険.xlsx -> シート名: '三井住友海上火災保険'
# [OK] 大林組.xlsx -> シート名: '大林組'
# [OK] 神戸製鋼所.xlsx -> シート名: '神戸製鋼所'
# [OK] 読売新聞社.xlsx -> シート名: '読売新聞社'
# [OK] 味の素.xlsx -> シート名: '味の素'
# [OK] 森永乳業.xlsx -> シート名: '森永乳業'
# [OK] 日本経済新聞社.xlsx -> シート名: '日本経済新聞社'
# [OK] 三菱電機.xlsx -> シート名: '三菱電機'
# [OK] コナミグループ.xlsx -> シート名: 'コナミグループ'
# [OK] 伊藤園.xlsx -> シート名: '伊藤園'
# [OK] 双日.xlsx -> シート名: '双日'
# [OK] アクセンチュア.xlsx -> シート名: 'アクセンチュア'
# [OK] ＪＦＥグループ.xlsx -> シート名: 'ＪＦＥグループ'
# [OK] 九州電力.xlsx -> シート名: '九州電力'
# [OK] ＮＨＫ.xlsx -> シート名: 'ＮＨＫ'
# [OK] ドコモグループ.xlsx -> シート名: 'ドコモグループ'
# [OK] 鹿島.xlsx -> シート名: '鹿島'
# [OK] ＡＬＳＯＫ.xlsx -> シート名: 'ＡＬＳＯＫ'
# [OK] ゆうちょ銀行.xlsx -> シート名: 'ゆうちょ銀行'
# [OK] 大和ハウス工業.xlsx -> シート名: '大和ハウス工業'
# [OK] ＢＩＰＲＯＧＹ.xlsx -> シート名: 'ＢＩＰＲＯＧＹ'
# [OK] 博報堂／博報堂ＤＹメディアパートナーズ.xlsx -> シート名: '博報堂／博報堂ＤＹメディアパートナーズ'
# [OK] ＮＥＣ.xlsx -> シート名: 'ＮＥＣ'
# [OK] ＮＴＴ西日本.xlsx -> シート名: 'ＮＴＴ西日本'
# [OK] 竹中工務店.xlsx -> シート名: '竹中工務店'
# [OK] ホンダ.xlsx -> シート名: 'ホンダ'
# [OK] ＴＤＫ.xlsx -> シート名: 'ＴＤＫ'
# [OK] テレビ東京.xlsx -> シート名: 'テレビ東京'
# [OK] ＩＨＩ.xlsx -> シート名: 'ＩＨＩ'
# [OK] 清水建設.xlsx -> シート名: '清水建設'
# [OK] 三井住友信託銀行.xlsx -> シート名: '三井住友信託銀行'
# [OK] ＪＲ東海.xlsx -> シート名: 'ＪＲ東海'
# [OK] 野村総合研究所.xlsx -> シート名: '野村総合研究所'
# [OK] 東レ.xlsx -> シート名: '東レ'
# [OK] 小学館.xlsx -> シート名: '小学館'
# [OK] かんぽ生命保険.xlsx -> シート名: 'かんぽ生命保険'
# [OK] アビームコンサルティング.xlsx -> シート名: 'アビームコンサルティング'
# [OK] 塩野義製薬.xlsx -> シート名: '塩野義製薬'
# [OK] キヤノン.xlsx -> シート名: 'キヤノン'
# [OK] 丸紅.xlsx -> シート名: '丸紅'
# [OK] 東芝.xlsx -> シート名: '東芝'
# [OK] 日本郵政.xlsx -> シート名: '日本郵政'
# [OK] 中部電力.xlsx -> シート名: '中部電力'
# [OK] 毎日新聞社.xlsx -> シート名: '毎日新聞社'
# [OK] ＮＴＴデータグループ.xlsx -> シート名: 'ＮＴＴデータグループ'
# [OK] 大成建設.xlsx -> シート名: '大成建設'
# [OK] デンソー.xlsx -> シート名: 'デンソー'
# [OK] 富士フイルム.xlsx -> シート名: '富士フイルム'
# [OK] 三菱ＵＦＪ銀行.xlsx -> シート名: '三菱ＵＦＪ銀行'
# [OK] ＬＩＸＩＬ.xlsx -> シート名: 'ＬＩＸＩＬ'
# [OK] レゾナック.xlsx -> シート名: 'レゾナック'
# [OK] シャープ.xlsx -> シート名: 'シャープ'
# [OK] マツダ.xlsx -> シート名: 'マツダ'
# [OK] 日本製鉄.xlsx -> シート名: '日本製鉄'
# [OK] リコー.xlsx -> シート名: 'リコー'
# [OK] 岡三証券.xlsx -> シート名: '岡三証券'
# [OK] ＹＫＫ／ＹＫＫ ＡＰ.xlsx -> シート名: 'ＹＫＫ／ＹＫＫ ＡＰ'
# [OK] ＪＲ西日本.xlsx -> シート名: 'ＪＲ西日本'
# [OK] 日本テレビ放送網.xlsx -> シート名: '日本テレビ放送網'
# [OK] 講談社.xlsx -> シート名: '講談社'
# [OK] エーザイ.xlsx -> シート名: 'エーザイ'
# [OK] 住友生命保険.xlsx -> シート名: '住友生命保険'
# [OK] テルモ.xlsx -> シート名: 'テルモ'
# [OK] アコム.xlsx -> シート名: 'アコム'
# [OK] いすゞ自動車.xlsx -> シート名: 'いすゞ自動車'
# [OK] 良品計画.xlsx -> シート名: '良品計画'
# [OK] 積水ハウス.xlsx -> シート名: '積水ハウス'
# [OK] サイバーエージェント.xlsx -> シート名: 'サイバーエージェント'
# [OK] 大塚商会.xlsx -> シート名: '大塚商会'
# [OK] 第一生命保険.xlsx -> シート名: '第一生命保険'
# [OK] 東京電力.xlsx -> シート名: '東京電力'
# [OK] 中外製薬.xlsx -> シート名: '中外製薬'
# [OK] 集英社.xlsx -> シート名: '集英社'
# [OK] 花王.xlsx -> シート名: '花王'
# [OK] クボタ.xlsx -> シート名: 'クボタ'
# [OK] 三菱商事.xlsx -> シート名: '三菱商事'
# [OK] フジテレビジョン.xlsx -> シート名: 'フジテレビジョン'
# [OK] ＰｗＣコンサルティング.xlsx -> シート名: 'ＰｗＣコンサルティング'
# [OK] ミネベアミツミ.xlsx -> シート名: 'ミネベアミツミ'
# [OK] 関西電力.xlsx -> シート名: '関西電力'
# [OK] みずほフィナンシャルグループ.xlsx -> シート名: 'みずほフィナンシャルグループ'
# [OK] オリエンタルランド.xlsx -> シート名: 'オリエンタルランド'
# [OK] 商工組合中央金庫.xlsx -> シート名: '商工組合中央金庫'
# [OK] 電通.xlsx -> シート名: '電通'
# [OK] 明治安田生命保険.xlsx -> シート名: '明治安田生命保険'
# [OK] 損害保険ジャパン.xlsx -> シート名: '損害保険ジャパン'
# [OK] 野村不動産.xlsx -> シート名: '野村不動産'
# [OK] 東京エレクトロングループ.xlsx -> シート名: '東京エレクトロングループ'
# [OK] 日揮ホールディングス.xlsx -> シート名: '日揮ホールディングス'
# [OK] ニトリ.xlsx -> シート名: 'ニトリ'
# [OK] 住友電気工業.xlsx -> シート名: '住友電気工業'
# [OK] ＥＮＥＯＳ.xlsx -> シート名: 'ＥＮＥＯＳ'
# [OK] ＴＢＳテレビ.xlsx -> シート名: 'ＴＢＳテレビ'
# [OK] 東京海上日動火災保険.xlsx -> シート名: '東京海上日動火災保険'
# [OK] 東海東京フィナンシャル・ホールディングス.xlsx -> シート名: '東海東京フィナンシャル・ホールディングス'
# [OK] キユーピー.xlsx -> シート名: 'キユーピー'
# [OK] 三菱ＵＦＪニコス.xlsx -> シート名: '三菱ＵＦＪニコス'
# [OK] 大塚製薬.xlsx -> シート名: '大塚製薬'
# [OK] 三菱マテリアル.xlsx -> シート名: '三菱マテリアル'
# [OK] オービック.xlsx -> シート名: 'オービック'
# [OK] ローソン.xlsx -> シート名: 'ローソン'
# [OK] セブン‐イレブン・ジャパン.xlsx -> シート名: 'セブン‐イレブン・ジャパン'
# [OK] パナソニック.xlsx -> シート名: 'パナソニック'
# [OK] 日本生命保険.xlsx -> シート名: '日本生命保険'
# [OK] ヤマハ発動機.xlsx -> シート名: 'ヤマハ発動機'
# [OK] トヨタ自動車.xlsx -> シート名: 'トヨタ自動車'
# [OK] ソニーグループ.xlsx -> シート名: 'ソニーグループ'
# [OK] 三井住友銀行.xlsx -> シート名: '三井住友銀行'
# [OK] タカラスタンダード.xlsx -> シート名: 'タカラスタンダード'
# [OK] 日立ソリューションズ.xlsx -> シート名: '日立ソリューションズ'
# [OK] 三井不動産.xlsx -> シート名: '三井不動産'
# [OK] 関西みらい銀行.xlsx -> シート名: '関西みらい銀行'
# [OK] ＪＲ東日本.xlsx -> シート名: 'ＪＲ東日本'
# [OK] 日本航空.xlsx -> シート名: '日本航空'
# [OK] ＡＧＣ.xlsx -> シート名: 'ＡＧＣ'
# [OK] ＪＴ.xlsx -> シート名: 'ＪＴ'
# [OK] ＴＯＴＯ.xlsx -> シート名: 'ＴＯＴＯ'
# [OK] あいおいニッセイ同和損害保険.xlsx -> シート名: 'あいおいニッセイ同和損害保険'
# [OK] リクルート.xlsx -> シート名: 'リクルート'
# [OK] りそなグループ.xlsx -> シート名: 'りそなグループ'
# [OK] 明治グループ.xlsx -> シート名: '明治グループ'
# [OK] 日本銀行.xlsx -> シート名: '日本銀行'
# [OK] ＮＴＴ東日本.xlsx -> シート名: 'ＮＴＴ東日本'
# [OK] ローム.xlsx -> シート名: 'ローム'
# [OK] 戸田建設.xlsx -> シート名: '戸田建設'
# [OK] セキスイハイムグループ.xlsx -> シート名: 'セキスイハイムグループ'
# [OK] Ｓｋｙ.xlsx -> シート名: 'Ｓｋｙ'
# [OK] 東北電力.xlsx -> シート名: '東北電力'
# [OK] 村田製作所.xlsx -> シート名: '村田製作所'
# [OK] 野村証券.xlsx -> シート名: '野村証券'
# [OK] ＮＥＣソリューションイノベータ.xlsx -> シート名: 'ＮＥＣソリューションイノベータ'
# [OK] トランスコスモス.xlsx -> シート名: 'トランスコスモス'
# [OK] 住友商事.xlsx -> シート名: '住友商事'
# [OK] 三井物産.xlsx -> シート名: '三井物産'
# [OK] エイチ・アイ・エス.xlsx -> シート名: 'エイチ・アイ・エス'
# [OK] ＳＭＢＣ日興証券.xlsx -> シート名: 'ＳＭＢＣ日興証券'
# [OK] 大阪ガス.xlsx -> シート名: '大阪ガス'
# [OK] 川崎重工業.xlsx -> シート名: '川崎重工業'
# [OK] 伊藤忠商事.xlsx -> シート名: '伊藤忠商事'
# [OK] 日本通運.xlsx -> シート名: '日本通運'
# [OK] 三井化学.xlsx -> シート名: '三井化学'
# [OK] ベネッセコーポレーション.xlsx -> シート名: 'ベネッセコーポレーション'
# [OK] 横浜銀行.xlsx -> シート名: '横浜銀行'
# [OK] 第一三共.xlsx -> シート名: '第一三共'
# [OK] キリン.xlsx -> シート名: 'キリン'
# [OK] デロイトトーマツコンサルティング.xlsx -> シート名: 'デロイトトーマツコンサルティング'
# [OK] ＮＴＴ（持株会社）.xlsx -> シート名: 'ＮＴＴ（持株会社）'
# [OK] 日本ＩＢＭ.xlsx -> シート名: '日本ＩＢＭ'
# [OK] 京都銀行.xlsx -> シート名: '京都銀行'
# [OK] 日産自動車.xlsx -> シート名: '日産自動車'
# [OK] 富士電機.xlsx -> シート名: '富士電機'
# [OK] 豊田自動織機.xlsx -> シート名: '豊田自動織機'
# [OK] ＪＴＢ.xlsx -> シート名: 'ＪＴＢ'
# [OK] 三菱地所.xlsx -> シート名: '三菱地所'
# [OK] 東京ガス.xlsx -> シート名: '東京ガス'
# [OK] ＳＣＳＫ.xlsx -> シート名: 'ＳＣＳＫ'
# [OK] 旭化成グループ.xlsx -> シート名: '旭化成グループ'
# [OK] ルネサスエレクトロニクス.xlsx -> シート名: 'ルネサスエレクトロニクス'
# [OK] サントリーグループ.xlsx -> シート名: 'サントリーグループ'
# [OK] ＴＩＳ.xlsx -> シート名: 'ＴＩＳ'
# [OK] 朝日新聞社.xlsx -> シート名: '朝日新聞社'
# [OK] アステラス製薬.xlsx -> シート名: 'アステラス製薬'
# [OK] 古河電気工業.xlsx -> シート名: '古河電気工業'
# [OK] 日本郵便.xlsx -> シート名: '日本郵便'
# [OK] メイテック.xlsx -> シート名: 'メイテック'
# [OK] 大日本印刷.xlsx -> シート名: '大日本印刷'
# [OK] 長谷工コーポレーション.xlsx -> シート名: '長谷工コーポレーション'
# [OK] 出光興産.xlsx -> シート名: '出光興産'
# [OK] ジェーシービー.xlsx -> シート名: 'ジェーシービー'
# [OK] ＴＯＰＰＡＮ.xlsx -> シート名: 'ＴＯＰＰＡＮ'
# [OK] スズキ.xlsx -> シート名: 'スズキ'
# [OK] 三菱重工業.xlsx -> シート名: '三菱重工業'
# [OK] オリエントコーポレーション.xlsx -> シート名: 'オリエントコーポレーション'
# [OK] アルファシステムズ.xlsx -> シート名: 'アルファシステムズ'
# [OK] 福岡銀行.xlsx -> シート名: '福岡銀行'
# [OK] 三菱自動車工業.xlsx -> シート名: '三菱自動車工業'
# [OK] 山崎製パン.xlsx -> シート名: '山崎製パン'
# [OK] 大和証券.xlsx -> シート名: '大和証券'
# [OK] 住友化学.xlsx -> シート名: '住友化学'
# [OK] アマゾンジャパン.xlsx -> シート名: 'アマゾンジャパン'
# [OK] ＥＹストラテジー・アンド・コンサルティング.xlsx -> シート名: 'ＥＹストラテジー・アンド・コンサルティング'
# [OK] 京セラ.xlsx -> シート名: '京セラ'
# [OK] ＫＤＤＩ.xlsx -> シート名: 'ＫＤＤＩ'
# [OK] ダイハツ工業.xlsx -> シート名: 'ダイハツ工業'
# [OK] ＫＡＤＯＫＡＷＡ.xlsx -> シート名: 'ＫＡＤＯＫＡＷＡ'
# [OK] 青山商事.xlsx -> シート名: '青山商事'
# [OK] 五洋建設.xlsx -> シート名: '五洋建設'
# [OK] ＳＵＢＡＲＵ.xlsx -> シート名: 'ＳＵＢＡＲＵ'
# [OK] セイコーエプソン.xlsx -> シート名: 'セイコーエプソン'
# [OK] ファーストリテイリンググループ.xlsx -> シート名: 'ファーストリテイリンググループ'
# [OK] ＬＩＮＥヤフー.xlsx -> シート名: 'ＬＩＮＥヤフー'
# [OK] 楽天グループ.xlsx -> シート名: '楽天グループ'
# [OK] 日東電工.xlsx -> シート名: '日東電工'
# [OK] コマツ.xlsx -> シート名: 'コマツ'
# [OK] 住友林業.xlsx -> シート名: '住友林業'
# [OK] 千葉銀行グループ.xlsx -> シート名: '千葉銀行グループ'
# [OK] 富士ソフト.xlsx -> シート名: '富士ソフト'
# [OK] 静岡銀行.xlsx -> シート名: '静岡銀行'
# [OK] 東武トップツアーズ.xlsx -> シート名: '東武トップツアーズ'
# [OK] 積水化学工業.xlsx -> シート名: '積水化学工業'
# [OK] 日立システムズ.xlsx -> シート名: '日立システムズ'
# [OK] インテック.xlsx -> シート名: 'インテック'
# [OK] 富士通.xlsx -> シート名: '富士通'
# [OK] 日本政策金融公庫.xlsx -> シート名: '日本政策金融公庫'
# [OK] 三菱ＵＦＪモルガン・スタンレー証券.xlsx -> シート名: '三菱ＵＦＪモルガン・スタンレー証券'
# [OK] アイシン.xlsx -> シート名: 'アイシン'
# [OK] キヤノンマーケティングジャパン.xlsx -> シート名: 'キヤノンマーケティングジャパン'
# [OK] オリックス.xlsx -> シート名: 'オリックス'
# [OK] キーエンス.xlsx -> シート名: 'キーエンス'
# [OK] セコム.xlsx -> シート名: 'セコム'
# [OK] 全日本空輸.xlsx -> シート名: '全日本空輸'
# [OK] ソフトバンク.xlsx -> シート名: 'ソフトバンク'
# [OK] 富士フイルムビジネスイノベーション.xlsx -> シート名: '富士フイルムビジネスイノベーション'
# [OK] 日立製作所.xlsx -> シート名: '日立製作所'
# [OK] ダイキン工業.xlsx -> シート名: 'ダイキン工業'
# [OK] テレビ朝日.xlsx -> シート名: 'テレビ朝日'
#
# 結合完了: job_hunting.xlsx (シート数: 217)
